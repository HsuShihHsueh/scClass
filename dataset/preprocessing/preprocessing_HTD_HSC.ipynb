# %%
import scanpy as sc
import numpy as np 
import pandas as pd
# openpyxl package to read excel# 'pip install openpyxl' if undownload it

# %%
supplementaryTable = "Supplementary table.xlsx"
dataset = "HTD_HSC"
CellType_ColumnName = 'celltype'
dataset_path = 'thymic-development-human-thymus-10XV2.loom'
metadata_path = 'thymus_annotated_matrix_files/HTA08.v01.A05.Science_human_hsc.csv'
anno_path = 'thymus_annotated_matrix_files/hsc_anno.npy'

# %%
# sign up and download by command (bulk download), url:
# https://data.humancellatlas.org/explore/projects/c1810dbc-16d2-45c3-b45e-3e675f88d87b/project-matrices
# this command is timeliness

# %%
# !wget -O thymic-development-human-thymus-10XV2.loom  'https://storage.googleapis.com/broad-datarepo-terra-prod-hca2-bucket/d30e68f8-c826-4639-88f3-ae35f00d4185/7e7a429d-e291-4f70-a36a-94bf252bd425/thymic-development-human-thymus-10XV2.loom?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=terra-data-repository%40broad-datarepo-terra-prod.iam.gserviceaccount.com%2F20220228%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220228T103946Z&X-Goog-Expires=900&X-Goog-SignedHeaders=host&X-Goog-Signature=...'
# !wget -O thymus_annotated_matrix_files.zip 'https://storage.googleapis.com/broad-datarepo-terra-prod-hca2-bucket/d30e68f8-c826-4639-88f3-ae35f00d4185/513466ae-6bd4-4e98-a129-5adee3be19be/thymus_annotated_matrix_files.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=terra-data-repository%40broad-datarepo-terra-prod.iam.gserviceaccount.com%2F20220228%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220228T103959Z&X-Goog-Expires=900&X-Goog-SignedHeaders=host&X-Goog-Signature=...'
# Out:
# --2022-02-28 18:43:10--  https://storage.googleapis.com/broad-datarepo-terra-prod-hca2-bucket/d30e68f8-c826-4639-88f3-ae35f00d4185/7e7a429d-e291-4f70-a36a-94bf252bd425/thymic-development-human-thymus-10XV2.loom?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=terra-data-repository%40broad-datarepo-terra-prod.iam.gserviceaccount.com%2F20220228%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220228T103946Z&X-Goog-Expires=900&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.160.80, 142.251.42.240, 142.251.43.16, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.160.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3463759651 (3.2G) [application/octet-stream]
# Saving to: ‘thymic-development-human-thymus-10XV2.loom’
#
# thymic-development- 100%[===================>]   3.23G   167MB/s    in 17s
#
# ...

# %%
# !mkdir thymus_annotated_matrix_files
# !mv thymus_annotated_matrix_files.zip thymus_annotated_matrix_files/
# !cd thymus_annotated_matrix_files;unzip thymus_annotated_matrix_files.zip
# Out:
# Archive:  thymus_annotated_matrix_files.zip
#   inflating: HTA08.v01.A05.Science_human_epi.csv
#   inflating: HTA08.v01.A05.Science_human_epi.h5ad
#   inflating: HTA08.v01.A05.Science_human_fig1.csv
#   inflating: HTA08.v01.A05.Science_human_fig1.h5ad
#   inflating: HTA08.v01.A05.Science_human_hsc.csv
#   inflating: HTA08.v01.A05.Science_human_hsc.h5ad
#   inflating: HTA08.v01.A06.Science_human_tcells.csv
#   inflating: HTA08.v01.A06.Science_human_tcells.h5ad
#   inflating: HTA08.v02.A04.Science_mouse_stromal.csv
#   inflating: HTA08.v02.A04.Science_mouse_stromal.h5ad
#   inflating: HTA08.v02.A04.Science_mouse_total.csv
#   inflating: HTA08.v02.A04.Science_mouse_total.h5ad
#   inflating: Data_navigator.ipynb

# %%
adata = sc.read_loom(dataset_path)
adata.obs
# Out:
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#                   antisense_reads  cell_barcode_fraction_bases_above_30_mean  \
# CellID
# CCCTCCTCATCTACGA                0                                   0.961287
# CGACCTTAGCAGATCG                0                                   0.961594
# AGAGCTTTCACAATGC                0                                   0.965387
# ACGAGCCTCATCTGTT                0                                   0.951984
# CAACCTCGTTCGGGCT                0                                   0.956643
# ...                           ...                                        ...
# GCATACAGTGTGGTTT                0                                   0.979769
# TCTCATATCGGATGGA                0                                   0.920408
# CGTCAGGTCTGCCCTA                0                                   0.844002
# ...

# %%
df = pd.read_csv(metadata_path)
df

# %%
sample_loom = {
    "biomaterial_id":["F21_TH_45N", "F23_TH_45N", "F45_TH_45N", "F45_TH_45P", "F29_TH_45P", "F21_TH_45P", "A16_TH_TOT_8", "A16_TH_TOT_1", "A16_TH_TOT_3", "F30_TH_45N", "F38_TH_45P", "A16_TH_TOT_2", "F38_TH_45N_2", "F22_TH_TOT", "F41_TH_45P", "A16_TH_TOT_5", "F38_TH_45N_1", "A16_TH_TOT_6", "A16_TH_TOT_7", "A16_TH_TOT_4", "F29_TH_45N", "F30_TH_45P", "F23_TH_45P", "F41_TH_45N"],
    "document_id":['1dfdfd8d-ae7b-41fb-a79d-75422d2107a5','21ecc37a-b8f8-4133-9cee-4a37fd36aa23','27c3c840-341e-40b6-b594-8d750a76e7cd','3ea09d23-1c49-4822-9477-8c853bc36360','4251717d-b1e1-4ca5-bebe-f48e28246e21','45e4f890-2e0b-4ea3-91c8-ef5eb36f915c','485e025d-19b9-4dca-a6e6-af98e51c9803','60d58745-f5c5-4f52-8a8b-59f9349b774d','6b4fa370-31ee-4927-ac54-200e58b8e047','88cd73da-6972-4415-bcb1-248d162ce39c','8cba8569-bd3b-428f-9fac-3b9b70b53994','90e83ff3-6db5-49d0-93e2-2924fee899ef','9679d05b-d454-4900-b995-ac8c715e9a64','9a92a706-ccff-40d6-82e6-859860ef110f','a2960c2a-611a-4327-99ac-2af958bd0b4b','a4154df0-1b7b-438b-8a49-f68895bd5c6a','b10eb4e3-4fe5-4dbd-9090-1d6cf2bc8f33','b8f9113a-c96c-40d4-bfc0-6eb5fd1eadcc','be5303e5-9aa2-4f87-942e-b6fecc060d78','c262b368-07ed-40ba-8b1d-27304aab9d98','c6d4bae1-260f-4dc0-9671-ab10191ad09b','e362be32-386d-49a1-b5d4-5221f92dfcd4','e80247e2-0a69-4976-bad4-c5892853c21b','eacf5112-4f08-4100-8b8b-bc24b6a89483'],
    "file_id":['FCAImmP7179370','FCAImmP7198635','FCAImmP7579219','FCAImmP7579218','FCAImmP7277556','FCAImmP7179369','4861STDY7462264','4861STDY7462257','4861STDY7462259','FCAImmP7277565','FCAImmP7528283','4861STDY7462258','FCAImmP7528285','FCAImmP7198432','FCAImmP7555851','4861STDY7462261','FCAImmP7528284','4861STDY7462262','4861STDY7462263','4861STDY7462260','FCAImmP7277557','FCAImmP7277564','FCAImmP7198634','FCAImmP7555852']
}

# %%
cell = {}
cell["index"] = [sample_loom["document_id"].index(_id) for _id in adata.obs["input_id"]]
cell["file_id"] = np.array(sample_loom["file_id"])[cell["index"]]
cell["csv_id"] = [a+"-"+b for a,b in zip(cell["file_id"],np.array(adata.obs_names))]

# %%
df_anno = df["Anno_level_fig1"].values
df_index = df["index"].values

# %%
from concurrent.futures import ProcessPoolExecutor

def func(u,i):
    if i%10000==0: print(i,"...")
    x = df_anno[df_index == u]
    return x[0] if x.shape[0] else ""

with ProcessPoolExecutor(max_workers=8) as executor:
    anno = [i for i in range(len(cell["csv_id"]))]
    label = executor.map(func,cell["csv_id"],anno)
    label = np.array(list(label)).astype("O")
    np.save(anno_path, label)

# %%
df = pd.read_excel(supplementaryTable, sheet_name=dataset)

# %%
label = np.load(anno_path,allow_pickle=True).astype(str)
adata.obs[CellType_ColumnName] = label
adata_select = adata[(label!=""),:]

# %%
adata_select.obs
# Out:
#                   antisense_reads  cell_barcode_fraction_bases_above_30_mean  \
# CellID
# CGACCTTAGCAGATCG                0                                   0.961594
# ACGAGCCTCATCTGTT                0                                   0.951984
# TACGGATAGCCATCGC                0                                   0.961779
# CCATTCGGTAAACCTC                0                                   0.962388
# CGACTTCCAGCTATTG                0                                   0.959622
# ...                           ...                                        ...
# AGAGCTTGTAGGGTAC                0                                   0.975880
# AGAGCGAAGGGTCGAT                0                                   0.971236
# AACGTTGGTTACGCGC                0                                   0.970889
# CGGACGTTCTGCAAGT                0                                   0.975751
# CCTAAAGAGTCGTTTG                0                                   0.973218
#
# ...

# %%
def add_celltype(adata,celltype_columnname):
    adata.obs[celltype_columnname] = adata.obs[celltype_columnname].astype("category")
    Transferlist = [np.where(df['origin cell type']==CellTypeList)[0][0] for CellTypeList in adata.obs[celltype_columnname].values.categories]
    adata.obs['modelA id'] = df['modelA id'][Transferlist].values[adata.obs[celltype_columnname].values.codes]
    adata.obs['modelC id'] = df['modelC id'][Transferlist].values[adata.obs[celltype_columnname].values.codes]
    adata.obs['transfer cell type'] = df['transfer cell type'][Transferlist].values[adata.obs[celltype_columnname].values.codes]
add_celltype(adata_select,CellType_ColumnName)
# Out:
# Trying to set attribute `.obs` of view, copying.
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
adata_select.obs['origin cell type'] = adata_select.obs['celltype']

# %%
adata_select.obs
# Out:
#                   antisense_reads  cell_barcode_fraction_bases_above_30_mean  \
# CellID
# CGACCTTAGCAGATCG                0                                   0.961594
# ACGAGCCTCATCTGTT                0                                   0.951984
# TACGGATAGCCATCGC                0                                   0.961779
# CCATTCGGTAAACCTC                0                                   0.962388
# CGACTTCCAGCTATTG                0                                   0.959622
# ...                           ...                                        ...
# AGAGCTTGTAGGGTAC                0                                   0.975880
# AGAGCGAAGGGTCGAT                0                                   0.971236
# AACGTTGGTTACGCGC                0                                   0.970889
# CGGACGTTCTGCAAGT                0                                   0.975751
# CCTAAAGAGTCGTTTG                0                                   0.973218
#
# ...

# %%
adata_select.write_h5ad(f'../{dataset}.h5ad')
# Out:
# /home/shhsu/.local/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'input_id' as categorical
# /home/shhsu/.local/lib/python3.9/site-packages/anndata/_core/anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'transfer cell type' as categorical
# ...
