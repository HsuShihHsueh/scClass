# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt

# %%
scClass_path = !cd ../scClass_modelC;pwd
scClass_path = str(scClass_path.n)
import sys; sys.path.append(scClass_path)
import scClass

# %%
y = pd.read_csv('scCaps/scClass_data/y_pred_PBMC68k_subsampling.csv',header=None)
y_true = y.values[:,0]
y_pred = y.values[:,1]

# %%
y_true
# Out:
# array([10, 10, 10, ...,  9,  9,  9])

# %%
y_pred
# Out:
# array([10, 10, 10, ...,  9,  9,  9])

# %%
fig = scClass.confusion_matrix(y_pred,y_true,filter=True)
scClass.figure_html(fig)
# Out:
# total acc: 86.17481397553084 %
#     <div class="flex" style='display: flex;flex-direction: row;'>
#       <div>
#         <img src='data:image/png;base64,...' style="width:450px;height:450px;object-fit:none;object-position:-20px -20px;">
#       </div>
#       <div style="padding-top:18px;">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>-1</th>
#       <td>unknown</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>T-helper cell</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>cytotoxic T cell</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>memory B cell</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>naive B cell</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>plasma cell</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>natural killer cell</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>erythrocyte</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>megakaryocyte</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>monocyte</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>dendritic cell</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>BM hematopoietic cell</td>
#     </tr>
#   </tbody>
# </table>
#       </div>

# %%
y_pred[y_pred==2] = 3
scClass.plot_performance(y_pred,y_true)
# Out:
# /home/shhsu/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   Performance     Value
# 0     accuary  0.861748
# 1   precision  0.895864
# 2      recall  0.804887
# 3    f1-score  0.792435
