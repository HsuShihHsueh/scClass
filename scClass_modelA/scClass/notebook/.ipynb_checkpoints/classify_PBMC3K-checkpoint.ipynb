# %%
import numpy as np
import pandas as pd
import scanpy as sc
from scipy import sparse 
import matplotlib.pyplot as plt
import torch

# %%
scClass_path = !cd ../..;pwd
scClass_path = str(scClass_path.n)
import sys; sys.path.append(scClass_path)
import scClass
from scClass.main import Model

# %% [markdown]
# ## Dataset Preprocessing

# %%
adata = sc.read_h5ad('../../../dataset/PBMC3K.h5ad')

# %%
# get gene on model
gene = adata.var["gene_ids"].values
adata = scClass.transmodel(adata,gene=gene,gene_ref='ensembl_ids')
# Out:
# /home/shhsu/.local/lib/python3.9/site-packages/anndata/_core/anndata.py:120: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# get gene seq...
# 0% 15% 30% 45% 61% 76% 91%
# Of 32738 genes in the input file, 27518 were found in the training set of 45468 genes.
# mapping to model...
# 0%

# %%
# Normalized
adata = scClass.normalize_simple(adata)

# %% [markdown]
# ## Classifier

# %%
model = scClass.load()
# Out:
# loading model from:  /home/shhsu/download/scClass_docker/scClass/scClass_modelA/scClass/data/model_train.pkl

# %%
y_pred = scClass.predict_batch(adata,model)

# %%
scClass.save_predict(y_pred)
# Out:
# label stored in: './output/cell_type_20220307_182700.csv'

# %% [markdown]
# ## Compare

# %%
df = pd.read_excel("../../../dataset/preprocessing/Supplementary table.xlsx", sheet_name='PBMC3K')
trans_table = df[['origin cell type','modelA id']].values.astype(str)
trans_table
# Out:
# array([['CD4 T cells', '0'],
#        ['CD8 T cells', '1'],
#        ['B cells', '3'],
#        ['NK cells', '7'],
#        ['Megakaryocytes', '9'],
#        ['CD14+ Monocytes', '10'],
#        ['FCGR3A+ Monocytes', '10'],
#        ['Dendritic cells', '11']], dtype='<U17')

# %%
label = adata.obs['modelA id']
anno = adata.obs['origin cell type']

# %%
fig = scClass.confusion_matrix(y_pred=y_pred,y_true=label)
scClass.figure_html(fig)
# Out:
#     <div class="flex" style='display: flex;flex-direction: row;'>
#       <div>
#         <img src='data:image/png;base64,...' style="width:450px;height:450px;object-fit:none;object-position:-20px -20px;">
#       </div>
#       <div style="padding-top:18px;">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>-1</th>
#       <td>unknown</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>T-helper cell</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>cytotoxic T cell</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>memory B cell</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>naive B cell</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>plasma cell</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>precursor B cell</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>pro-B cell</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>natural killer cell</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>erythrocyte</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>megakaryocyte</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>monocyte</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>dendritic cell</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>BM hematopoietic cell</td>
#     </tr>
#   </tbody>
# </table>
#       </div>

# %%
scClass.heatmap_matrix(y_pred=y_pred,y_true=anno,table=trans_table)

# %%
y_pred[y_pred==2] = 3 #B cell
scClass.plot_performance(y_pred=y_pred,y_true=label)
# Out:
#   Performance     Value
# 0     accuary  0.898787
# 1   precision  0.906116
# 2      recall  0.898647
# 3    f1-score  0.900760
